# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import rdFingerprintGenerator
from rdkit.DataStructs.cDataStructs import TanimotoSimilarity
from typing import Tuple
from tqdm import tqdm

# %%
def get_morgan_fingerprint(mol: Chem.Mol) -> rdFingerprintGenerator.MorganFP:
    """
    Get the fingerprint of a molecule.
    """
    mfpgen = rdFingerprintGenerator.GetMorganGenerator(radius=2, fpSize=2048)
    return mfpgen.GetFingerprint(mol)

def calculate_tanimoto(mol1: Chem.Mol,
                       mol2: Chem.Mol) -> float:
    if mol1 is None or mol2 is None:
        return 0
    # do full circle back to smiles to mol
    mol1, mol2 = Chem.MolFromSmiles(Chem.MolToSmiles(mol1)), Chem.MolFromSmiles(Chem.MolToSmiles(mol2))
    fp1 = get_morgan_fingerprint(mol1)
    fp2 = get_morgan_fingerprint(mol2)
    return TanimotoSimilarity(fp1, fp2)

# %%
df = pd.read_csv('sept23_syndirella_CHIKV_MAC_final_car_routes.csv')
df
# Out:
#             1_r1_smiles                  1_r2_smiles  \
# 0         NC1CCC(=O)NC1   NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 1   O=C(O)COc1cccc(F)c1               CNCc1cccc(O)n1
# 2        CNCc1ccc(O)nc1            CCOc1ncccc1C(=O)O
# 3            NC1CCCC1CO        Clc1c(I)ccc2[nH]cnc12
# 4          NCc1ccc(O)s1             CCOC(=O)c1ccnn1C
# ..                  ...                          ...
# 64                 OCCl            Clc1ccc2c(c1)NCO2
# 65                 O=CO  CN(C)C(=O)CNc1cc[nH]c(=O)c1
# 66           Nc1ccccc1N            COCC(=O)OC(C)(C)C
# 67   CNCc1cccc(=O)[nH]1           CCOC(=O)c1cn[nH]c1
# 68   Cc1ccncc1NC(=O)CCl        Cc1[nH][nH]c(=O)c1CCO
#
#                               1_reaction          2_r1_smiles  \
# 0                              Amidation                  NaN
# 1                              Amidation                  NaN
# 2                              Amidation                  NaN
# 3             Buchwald-Hartwig_amination                  NaN
# 4                        Ester_amidation                  NaN
# ..                                   ...                  ...
# 64  Nucleophilic_substitution_with_amine  OCN1COc2ccc(Cl)cc21
# 65                             Amidation                  NaN
# 66                       Ester_amidation                  NaN
# 67                       Ester_amidation                  NaN
# 68  Nucleophilic_substitution_with_amine                  NaN
#
#         2_r2_smiles               2_reaction     compound_set  input_num  \
# 0               NaN                      NaN  cx1371a-cx0300a       44.0
# 1               NaN                      NaN  cx0540a-cx1118a      134.0
# 2               NaN                      NaN  cx0522a-cx1118a       50.0
# 3               NaN                      NaN  cx0894a-cx0406a      238.0
# 4               NaN                      NaN  cx0892a-cx1151a      128.0
# ..              ...                      ...              ...        ...
# 64  OB(O)c1ccn[nH]1  Sp2-sp2_Suzuki_coupling  cx0864d-cx0969b      300.0
# 65              NaN                      NaN  cx1076a-cx0721a      161.0
# 66              NaN                      NaN  cx0692a-cx1116a      283.0
# 67              NaN                      NaN  cx0732a-cx1135a       29.0
# 68              NaN                      NaN  cx0317a-cx0305a       58.0
#
#    route_uuid                                       smiles hit1_short  \
# 0      32fgo7  NC(=O)c1ccc(C(=O)N[C@@H]2CCC(=O)NC2)c(Cl)c1    cx1371a
# 1      qehMd6           CN(Cc1cccc(O)n1)C(=O)COc1cccc(F)c1    cx1118a
# 2      tTnD23             CCOc1ncccc1C(=O)N(C)Cc1ccc(O)nc1    cx0522a
# 3      bk89Er        OC[C@@H]1CCC[C@H]1Nc1ccc2[nH]cnc2c1Cl    cx0406a
# 4      8NWsBn                    Cn1nccc1C(=O)NCc1ccc(O)s1    cx1151a
# ..        ...                                          ...        ...
# 64     6ACutS                 OCN1COc2ccc(-c3ccn[nH]3)cc21    cx0864d
# 65     4DEaMj             CN(C)C(=O)CN(C=O)c1cc[nH]c(=O)c1    cx1076a
# 66     3bhpFq                           COCC(=O)Nc1ccccc1N    cx0692a
# 67     ZzGYCp          CN(Cc1cccc(=O)[nH]1)C(=O)c1cn[nH]c1    cx0732a
# 68     STWk5f         Cc1ccncc1NC(=O)Cn1[nH]c(=O)c(CCO)c1C    cx0317a
#
#    hit2_short             datetime  num_steps                   flat_inchi
# 0     cx0300a  2024-09-03 18:02:00        1.0  SMVDAYWKXWVCAN-UHFFFAOYSA-N
# 1     cx0540a  2024-09-04 10:07:00        1.0  MNLAWAQYKQVGLK-UHFFFAOYSA-N
# 2     cx1118a  2024-09-03 20:56:00        1.0  FCGOSHSMTQLVEX-UHFFFAOYSA-N
# 3     cx0894a  2024-09-04 11:35:00        1.0  WHLDZOYDHAHKLT-UHFFFAOYSA-N
# 4     cx0892a  2024-09-04 09:20:00        1.0  IMTCTUMLWQUKFC-UHFFFAOYSA-N
# ..        ...                  ...        ...                          ...
# 64    cx0969b  2024-09-04 11:31:00        2.0  CVNPYWIROGTFDL-UHFFFAOYSA-N
# 65    cx0721a  2024-09-04 09:09:00        1.0  KKYCNGMNUUPLTM-UHFFFAOYSA-N
# 66    cx1116a  2024-09-05 11:12:00        1.0  PPHADCGGEPSVTM-UHFFFAOYSA-N
# 67    cx1135a  2024-09-03 19:00:00        1.0  ZJENMQHSGLZNHL-UHFFFAOYSA-N
# 68    cx0305a  2024-09-03 18:00:00        1.0  GQXYNJMUNPQGML-UHFFFAOYSA-N
#
# [69 rows x 15 columns]

# %%
enamine = pd.read_excel('../quoting/Q1924016_CHIKV_Reactants.xlsx')
enamine
# Out:
#          ID                                    SMILES    Catalogue ID  \
# 0        15                           Nc1ccc2ncccc2c1     EN300-41836
# 1        18                    CNC1CCN(c2ccccc2F)C1=O    EN300-146245
# 2        19                     Cc1[nH][nH]c(=O)c1CCO    EN300-260735
# 3        25                      O=c1cc[nH]c(=O)[nH]1     EN300-17138
# 4        32                      COCC(=O)Nc1ccc(O)cc1     EN300-76300
# ...     ...                                       ...             ...
# 9926  91469  Cc1c(CCO)c(=O)[nH]n1S(=O)(=O)c1ccc(I)cc1  EN300-18644000
# 9927  91471     Cc1c(CCO)c(=O)[nH]n1C(=O)c1c(F)cccc1F  EN300-18636910
# 9928  91473    Cc1ccc(-n2[nH]c(C(=O)O)c(CCO)c2=O)cc1C    EN300-236836
# 9929  91475  Cc1ccc(S(=O)(=O)n2[nH]c(=O)c(CCO)c2C)cc1  EN300-25004434
# 9930  91477  Cc1cc(C)nc(-n2[nH]c(C(=O)O)c(CCO)c2=O)n1     EN300-54099
#
#       Price per 20mg, EUR  Price per 50mg, EUR  Price per 100mg, EUR  \
# 0                      17                   18                    18
# 1                       0                    0                     0
# 2                      17                   18                    27
# 3                      17                   18                    18
# 4                      56                   84                   125
# ...                   ...                  ...                   ...
# 9926                    0                    0                     0
# 9927                    0                    0                     0
# 9928                    0                    0                     0
# 9929                    0                    0                     0
# 9930                   26                   38                    56
#
#       Price per 250mg, EUR  Availability       Match Type  Purity, %  \
# 0                       18      In stock      Exact match       95.0
# 1                        0      In stock  Other salt form       95.0
# 2                       38      In stock      Exact match       95.0
# 3                       18      In stock      Exact match       95.0
# 4                      179      In stock      Exact match       95.0
# ...                    ...           ...              ...        ...
# 9926                     0  Out of stock      Exact match       95.0
# 9927                     0  Out of stock      Exact match       95.0
# 9928                     0  Out of stock      Exact match       95.0
# 9929                     0  Out of stock      Exact match       95.0
# 9930                    80      In stock      Exact match      100.0
#
#      Alternative_stock_salt_form Alternative_stock_stereo_form
# 0                            NaN                           NaN
# 1                    EN300-75310                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ...                          ...                           ...
# 9926                         NaN                           NaN
# 9927                         NaN                           NaN
# 9928                         NaN                           NaN
# 9929                         NaN                           NaN
# 9930                         NaN                           NaN
#
# [9931 rows x 12 columns]

# %%
# just check if any intermediate is in enamine
#df = routes[routes['2_r1_smiles'].notna()]

# %%
df.fillna('', inplace=True)

# %%
# go through row by row
for i, irow in tqdm(df.iterrows()):
    # check if all reactants in enamine
    for j, jrow in enamine[enamine['Availability'] == 'In stock'].iterrows():
        if calculate_tanimoto(Chem.MolFromSmiles(irow['1_r1_smiles']), Chem.MolFromSmiles(jrow['SMILES'])) == 1.0:
            df.loc[i, '1_r1'] = jrow['Catalogue ID']
        if calculate_tanimoto(Chem.MolFromSmiles(irow['1_r2_smiles']), Chem.MolFromSmiles(jrow['SMILES'])) == 1.0:
            df.loc[i, '1_r2'] = jrow['Catalogue ID']
        if calculate_tanimoto(Chem.MolFromSmiles(irow['2_r1_smiles']), Chem.MolFromSmiles(jrow['SMILES'])) == 1.0:
            df.loc[i, '2_r1'] = jrow['Catalogue ID']
        if calculate_tanimoto(Chem.MolFromSmiles(irow['2_r2_smiles']), Chem.MolFromSmiles(jrow['SMILES'])) == 1.0:
            df.loc[i, '2_r2'] = jrow['Catalogue ID']
# Out:
# 69it [09:15,  8.05s/it]

# %%
df
# Out:
#             1_r1_smiles                  1_r2_smiles  \
# 0         NC1CCC(=O)NC1   NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 1   O=C(O)COc1cccc(F)c1               CNCc1cccc(O)n1
# 2        CNCc1ccc(O)nc1            CCOc1ncccc1C(=O)O
# 3            NC1CCCC1CO        Clc1c(I)ccc2[nH]cnc12
# 4          NCc1ccc(O)s1             CCOC(=O)c1ccnn1C
# ..                  ...                          ...
# 64                 OCCl            Clc1ccc2c(c1)NCO2
# 65                 O=CO  CN(C)C(=O)CNc1cc[nH]c(=O)c1
# 66           Nc1ccccc1N            COCC(=O)OC(C)(C)C
# 67   CNCc1cccc(=O)[nH]1           CCOC(=O)c1cn[nH]c1
# 68   Cc1ccncc1NC(=O)CCl        Cc1[nH][nH]c(=O)c1CCO
#
#                               1_reaction          2_r1_smiles  \
# 0                              Amidation
# 1                              Amidation
# 2                              Amidation
# 3             Buchwald-Hartwig_amination
# 4                        Ester_amidation
# ..                                   ...                  ...
# 64  Nucleophilic_substitution_with_amine  OCN1COc2ccc(Cl)cc21
# 65                             Amidation
# 66                       Ester_amidation
# 67                       Ester_amidation
# 68  Nucleophilic_substitution_with_amine
#
#         2_r2_smiles               2_reaction     compound_set  input_num  \
# 0                                             cx1371a-cx0300a       44.0
# 1                                             cx0540a-cx1118a      134.0
# 2                                             cx0522a-cx1118a       50.0
# 3                                             cx0894a-cx0406a      238.0
# 4                                             cx0892a-cx1151a      128.0
# ..              ...                      ...              ...        ...
# 64  OB(O)c1ccn[nH]1  Sp2-sp2_Suzuki_coupling  cx0864d-cx0969b      300.0
# 65                                            cx1076a-cx0721a      161.0
# 66                                            cx0692a-cx1116a      283.0
# 67                                            cx0732a-cx1135a       29.0
# 68                                            cx0317a-cx0305a       58.0
#
#    route_uuid                                       smiles hit1_short  \
# 0      32fgo7  NC(=O)c1ccc(C(=O)N[C@@H]2CCC(=O)NC2)c(Cl)c1    cx1371a
# 1      qehMd6           CN(Cc1cccc(O)n1)C(=O)COc1cccc(F)c1    cx1118a
# 2      tTnD23             CCOc1ncccc1C(=O)N(C)Cc1ccc(O)nc1    cx0522a
# 3      bk89Er        OC[C@@H]1CCC[C@H]1Nc1ccc2[nH]cnc2c1Cl    cx0406a
# 4      8NWsBn                    Cn1nccc1C(=O)NCc1ccc(O)s1    cx1151a
# ..        ...                                          ...        ...
# 64     6ACutS                 OCN1COc2ccc(-c3ccn[nH]3)cc21    cx0864d
# 65     4DEaMj             CN(C)C(=O)CN(C=O)c1cc[nH]c(=O)c1    cx1076a
# 66     3bhpFq                           COCC(=O)Nc1ccccc1N    cx0692a
# 67     ZzGYCp          CN(Cc1cccc(=O)[nH]1)C(=O)c1cn[nH]c1    cx0732a
# 68     STWk5f         Cc1ccncc1NC(=O)Cn1[nH]c(=O)c(CCO)c1C    cx0317a
#
#    hit2_short             datetime  num_steps                   flat_inchi  \
# 0     cx0300a  2024-09-03 18:02:00        1.0  SMVDAYWKXWVCAN-UHFFFAOYSA-N
# 1     cx0540a  2024-09-04 10:07:00        1.0  MNLAWAQYKQVGLK-UHFFFAOYSA-N
# 2     cx1118a  2024-09-03 20:56:00        1.0  FCGOSHSMTQLVEX-UHFFFAOYSA-N
# 3     cx0894a  2024-09-04 11:35:00        1.0  WHLDZOYDHAHKLT-UHFFFAOYSA-N
# 4     cx0892a  2024-09-04 09:20:00        1.0  IMTCTUMLWQUKFC-UHFFFAOYSA-N
# ..        ...                  ...        ...                          ...
# 64    cx0969b  2024-09-04 11:31:00        2.0  CVNPYWIROGTFDL-UHFFFAOYSA-N
# 65    cx0721a  2024-09-04 09:09:00        1.0  KKYCNGMNUUPLTM-UHFFFAOYSA-N
# 66    cx1116a  2024-09-05 11:12:00        1.0  PPHADCGGEPSVTM-UHFFFAOYSA-N
# 67    cx1135a  2024-09-03 19:00:00        1.0  ZJENMQHSGLZNHL-UHFFFAOYSA-N
# 68    cx0305a  2024-09-03 18:00:00        1.0  GQXYNJMUNPQGML-UHFFFAOYSA-N
#
#              1_r1            1_r2 2_r1          2_r2
# 0     EN300-56890             NaN  NaN           NaN
# 1     EN300-00073    EN300-702794  NaN           NaN
# 2   EN300-2855135     EN300-21350  NaN           NaN
# 3     EN300-76012  EN300-25644419  NaN           NaN
# 4             NaN             NaN  NaN           NaN
# ..            ...             ...  ...           ...
# 64            NaN             NaN  NaN  EN300-200298
# 65    EN300-19898             NaN  NaN           NaN
# 66    EN300-19093             NaN  NaN           NaN
# 67            NaN     EN300-93017  NaN           NaN
# 68            NaN    EN300-260735  NaN           NaN
#
# [69 rows x 19 columns]

# %%
df.to_csv('sept23_syndirella_CHIKV_MAC_final_car_routes_w_enamine.csv')

# %%
# Define the function to check if all reactants are in enamine
def check_reactants(row):
    if row['num_steps'] == 1:
        if row['1_r2_smiles'] == '':
            return not pd.isna(row['1_r1'])
        else:
            return not pd.isna(row['1_r1']) and not pd.isna(row['1_r2'])
    elif row['num_steps'] == 2:
        if row['1_r2_smiles'] == '':
            return not pd.isna(row['1_r1']) and (not pd.isna(row['2_r1']) or not pd.isna(row['2_r2']))
        return not pd.isna(row['1_r1']) and not pd.isna(row['1_r2']) and (not pd.isna(row['2_r1']) or not pd.isna(row['2_r2']))
    return False

# Apply the function to each row
df['all_reactants_in_enamine'] = df.apply(check_reactants, axis=1)
df
# Out:
#             1_r1_smiles                  1_r2_smiles  \
# 0         NC1CCC(=O)NC1   NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 1   O=C(O)COc1cccc(F)c1               CNCc1cccc(O)n1
# 2        CNCc1ccc(O)nc1            CCOc1ncccc1C(=O)O
# 3            NC1CCCC1CO        Clc1c(I)ccc2[nH]cnc12
# 4          NCc1ccc(O)s1             CCOC(=O)c1ccnn1C
# ..                  ...                          ...
# 64                 OCCl            Clc1ccc2c(c1)NCO2
# 65                 O=CO  CN(C)C(=O)CNc1cc[nH]c(=O)c1
# 66           Nc1ccccc1N            COCC(=O)OC(C)(C)C
# 67   CNCc1cccc(=O)[nH]1           CCOC(=O)c1cn[nH]c1
# 68   Cc1ccncc1NC(=O)CCl        Cc1[nH][nH]c(=O)c1CCO
#
#                               1_reaction          2_r1_smiles  \
# 0                              Amidation
# 1                              Amidation
# 2                              Amidation
# 3             Buchwald-Hartwig_amination
# 4                        Ester_amidation
# ..                                   ...                  ...
# 64  Nucleophilic_substitution_with_amine  OCN1COc2ccc(Cl)cc21
# 65                             Amidation
# 66                       Ester_amidation
# 67                       Ester_amidation
# 68  Nucleophilic_substitution_with_amine
#
#         2_r2_smiles               2_reaction     compound_set  input_num  \
# 0                                             cx1371a-cx0300a       44.0
# 1                                             cx0540a-cx1118a      134.0
# 2                                             cx0522a-cx1118a       50.0
# 3                                             cx0894a-cx0406a      238.0
# 4                                             cx0892a-cx1151a      128.0
# ..              ...                      ...              ...        ...
# 64  OB(O)c1ccn[nH]1  Sp2-sp2_Suzuki_coupling  cx0864d-cx0969b      300.0
# 65                                            cx1076a-cx0721a      161.0
# 66                                            cx0692a-cx1116a      283.0
# 67                                            cx0732a-cx1135a       29.0
# 68                                            cx0317a-cx0305a       58.0
#
#    route_uuid                                       smiles hit1_short  \
# 0      32fgo7  NC(=O)c1ccc(C(=O)N[C@@H]2CCC(=O)NC2)c(Cl)c1    cx1371a
# 1      qehMd6           CN(Cc1cccc(O)n1)C(=O)COc1cccc(F)c1    cx1118a
# 2      tTnD23             CCOc1ncccc1C(=O)N(C)Cc1ccc(O)nc1    cx0522a
# 3      bk89Er        OC[C@@H]1CCC[C@H]1Nc1ccc2[nH]cnc2c1Cl    cx0406a
# 4      8NWsBn                    Cn1nccc1C(=O)NCc1ccc(O)s1    cx1151a
# ..        ...                                          ...        ...
# 64     6ACutS                 OCN1COc2ccc(-c3ccn[nH]3)cc21    cx0864d
# 65     4DEaMj             CN(C)C(=O)CN(C=O)c1cc[nH]c(=O)c1    cx1076a
# 66     3bhpFq                           COCC(=O)Nc1ccccc1N    cx0692a
# 67     ZzGYCp          CN(Cc1cccc(=O)[nH]1)C(=O)c1cn[nH]c1    cx0732a
# 68     STWk5f         Cc1ccncc1NC(=O)Cn1[nH]c(=O)c(CCO)c1C    cx0317a
#
#    hit2_short             datetime  num_steps                   flat_inchi  \
# 0     cx0300a  2024-09-03 18:02:00        1.0  SMVDAYWKXWVCAN-UHFFFAOYSA-N
# 1     cx0540a  2024-09-04 10:07:00        1.0  MNLAWAQYKQVGLK-UHFFFAOYSA-N
# 2     cx1118a  2024-09-03 20:56:00        1.0  FCGOSHSMTQLVEX-UHFFFAOYSA-N
# 3     cx0894a  2024-09-04 11:35:00        1.0  WHLDZOYDHAHKLT-UHFFFAOYSA-N
# 4     cx0892a  2024-09-04 09:20:00        1.0  IMTCTUMLWQUKFC-UHFFFAOYSA-N
# ..        ...                  ...        ...                          ...
# 64    cx0969b  2024-09-04 11:31:00        2.0  CVNPYWIROGTFDL-UHFFFAOYSA-N
# 65    cx0721a  2024-09-04 09:09:00        1.0  KKYCNGMNUUPLTM-UHFFFAOYSA-N
# 66    cx1116a  2024-09-05 11:12:00        1.0  PPHADCGGEPSVTM-UHFFFAOYSA-N
# 67    cx1135a  2024-09-03 19:00:00        1.0  ZJENMQHSGLZNHL-UHFFFAOYSA-N
# 68    cx0305a  2024-09-03 18:00:00        1.0  GQXYNJMUNPQGML-UHFFFAOYSA-N
#
#              1_r1            1_r2 2_r1          2_r2  all_reactants_in_enamine
# 0     EN300-56890             NaN  NaN           NaN                     False
# 1     EN300-00073    EN300-702794  NaN           NaN                      True
# 2   EN300-2855135     EN300-21350  NaN           NaN                      True
# 3     EN300-76012  EN300-25644419  NaN           NaN                      True
# 4             NaN             NaN  NaN           NaN                     False
# ..            ...             ...  ...           ...                       ...
# 64            NaN             NaN  NaN  EN300-200298                     False
# 65    EN300-19898             NaN  NaN           NaN                     False
# 66    EN300-19093             NaN  NaN           NaN                     False
# 67            NaN     EN300-93017  NaN           NaN                     False
# 68            NaN    EN300-260735  NaN           NaN                     False
#
# [69 rows x 20 columns]

# %%
# multistep
df[df['num_steps'] == 2]
# Out:
#                   1_r1_smiles        1_r2_smiles  \
# 5           CC(C)(C)OC(=O)NCO
# 14  O=Cc1nn(CC(=O)O)c2ccccc12                CNC
# 18              O=c1cccc[nH]1     ClCc1noc(Br)n1
# 21             O=C1CCC(Cl)NN1                 CN
# 22  O=Cc1nn(CC(=O)O)c2ccccc12       Nc1ccc(O)cc1
# 32            Cc1cc(I)cc(F)n1             CNNC=O
# 33        Nc1ccc(O)c(B(O)O)c1          COCC(=O)O
# 34         N#Cc1c(O)ccc(N)c1F          COCC(=O)O
# 36    O=C(O)C(CS)c1cccc(Br)c1      NC1CCC(=O)NC1
# 39            Nc1cc(Br)c[nH]1               CCCO
# 49              O=c1cccc[nH]1     ClCc1noc(Br)n1
# 64                       OCCl  Clc1ccc2c(c1)NCO2
#
#                                            1_reaction  \
# 5                                  N-Boc_deprotection
# 14                                          Amidation
# 18               Nucleophilic_substitution_with_amine
# 21               Nucleophilic_substitution_with_amine
# 22                                Reductive_amination
# 32               N-nucleophilic_aromatic_substitution
# 33                                          Amidation
# 34                                          Amidation
# 36                                          Amidation
# 39  Mitsunobu_reaction_with_amine_alcohol_and_thio...
# 49               Nucleophilic_substitution_with_amine
# 64               Nucleophilic_substitution_with_amine
#
#                             2_r1_smiles                       2_r2_smiles  \
# 5                                   NCO        Cc1c(C(=O)O)ccnc1NC1CC=CC1
# 14                         Nc1ccc(O)cc1     CN(C)C(=O)Cn1nc(C=O)c2ccccc21
# 18               O=c1ccccn1Cc1noc(Br)n1                  CNc1nccc2ccccc12
# 21                       CNC1CCC(=O)NN1                 CCOc1ncccc1C(=O)O
# 22  O=C(O)Cn1nc(CNc2ccc(O)cc2)c2ccccc21                               CNC
# 32               Cc1cc(I)cc(N(C)NC=O)n1  CC(CCB1OC(C)(C)C(C)(C)O1)NC(N)=O
# 33         O=C1CCC(NC(=O)c2csc(I)n2)CN1       COCC(=O)Nc1ccc(O)c(B(O)O)c1
# 34           COCC(=O)Nc1ccc(O)c(C#N)c1F                         CNCC(N)=O
# 36  O=C1CCC(NC(=O)C(CS)c2cccc(Br)c2)CN1                           CCC(N)N
# 39                   CCCNc1cc(Br)c[nH]1                      CC(C)CCB(O)O
# 49                OB(O)c1cnc2[nH]ccc2c1            O=c1ccccn1Cc1noc(Br)n1
# 64                  OCN1COc2ccc(Cl)cc21                   OB(O)c1ccn[nH]1
#
#                               2_reaction        compound_set  input_num  \
# 5                              Amidation     cx0441a-cx0317a      171.0
# 14                   Reductive_amination     cx0935a-cx0312a      314.0
# 18  N-nucleophilic_aromatic_substitution     cx0353a-cx0316a      140.0
# 21                             Amidation     cx0522a-cx1135a       51.0
# 22                             Amidation     cx0312a-cx0935a      264.0
# 32               Sp3-sp2_Suzuki_coupling     cx0544a-cx1194a       33.0
# 33               Sp2-sp2_Suzuki_coupling     cx0935a-cx0300a      313.0
# 34  N-nucleophilic_aromatic_substitution     cx0935a-cx0553a      317.0
# 36            Buchwald-Hartwig_amination     cx1338a-cx0300a       40.0
# 39               Sp3-sp2_Suzuki_coupling     cx1278a-cx0353a      106.0
# 49               Sp2-sp2_Suzuki_coupling  CHIKVMac-DLS-DF001        9.0
# 64               Sp2-sp2_Suzuki_coupling     cx0864d-cx0969b      300.0
#
#    route_uuid                                             smiles hit1_short  \
# 5      wzbbXS                       Cc1c(C(=O)NCO)ccnc1NC1CC=CC1    cx0317a
# 14     fbhmej            CN(C)C(=O)Cn1nc(CNc2ccc(O)cc2)c2ccccc21    cx0935a
# 18     Bpx294             CN(c1nc(Cn2ccccc2=O)no1)c1nccc2ccccc12    cx0353a
# 21     e5WDiF               CCOc1ncccc1C(=O)N(C)[C@H]1CCC(=O)NN1    cx0522a
# 22     tCavCn            CN(C)C(=O)Cn1nc(CNc2ccc(O)cc2)c2ccccc21    cx0935a
# 32     oKid7K             Cc1cc(CC[C@H](C)NC(N)=O)cc(N(C)NC=O)n1    cx0544a
# 33     ZWFCao  COCC(=O)Nc1ccc(O)c(-c2nc(C(=O)N[C@@H]3CCC(=O)N...    cx0935a
# 34     sCHeek               COCC(=O)Nc1ccc(O)c(C#N)c1N(C)CC(N)=O    cx0935a
# 36     TqMXju  CC[C@H](N)Nc1cccc([C@@H](CS)C(=O)N[C@@H]2CCC(=...    cx1338a
# 39     BbS6ek                            CCCNc1cc(CCC(C)C)c[nH]1    cx1278a
# 49     ouPDhh              O=c1ccccn1Cc1noc(-c2cnc3[nH]ccc3c2)n1    cx1402a
# 64     6ACutS                       OCN1COc2ccc(-c3ccn[nH]3)cc21    cx0864d
#
#    hit2_short             datetime  num_steps                   flat_inchi  \
# 5     cx0441a  2024-09-04 09:36:00        2.0  YIIMVUSFSKUYCA-UHFFFAOYSA-N
# 14    cx0312a  2024-09-04 12:57:00        2.0  WLFMTZKZYACXSW-UHFFFAOYSA-N
# 18    cx0316a  2024-09-04 10:49:00        2.0  OYAFCPFGSBONSE-UHFFFAOYSA-N
# 21    cx1135a  2024-09-03 19:43:00        2.0  CTECJTBKOFPTMY-UHFFFAOYSA-N
# 22    cx0312a  2024-09-04 20:01:00        2.0  WLFMTZKZYACXSW-UHFFFAOYSA-N
# 32    cx1194a  2024-09-03 18:02:00        2.0  OYZLDUQCBJYBED-UHFFFAOYSA-N
# 33    cx0300a  2024-09-04 10:40:00        2.0  SBEBTLKTHHBVAY-UHFFFAOYSA-N
# 34    cx0553a  2024-09-04 14:44:00        2.0  XXPRWRCNORVHSY-UHFFFAOYSA-N
# 36    cx0300a  2024-09-05 16:16:00        2.0  JAHJLJNEYRGXQB-UHFFFAOYSA-N
# 39    cx0353a  2024-09-04 16:25:00        2.0  VXOZIAXPIMEJPP-UHFFFAOYSA-N
# 49    cx0316a  2024-09-03 19:06:00        2.0  LKSJOAHCUYUSRB-UHFFFAOYSA-N
# 64    cx0969b  2024-09-04 11:31:00        2.0  CVNPYWIROGTFDL-UHFFFAOYSA-N
#
#              1_r1         1_r2         2_r1           2_r2  \
# 5             NaN          NaN          NaN            NaN
# 14            NaN  EN300-30964  EN300-33645            NaN
# 18            NaN          NaN          NaN  EN300-1231023
# 21            NaN          NaN          NaN    EN300-21350
# 22            NaN  EN300-33645          NaN    EN300-30964
# 32   EN300-726488          NaN          NaN            NaN
# 33            NaN  EN300-20233          NaN            NaN
# 34  EN300-6802393  EN300-20233          NaN    EN300-41185
# 36            NaN  EN300-56890          NaN            NaN
# 39            NaN  EN300-19337          NaN  EN300-1252973
# 49            NaN          NaN          NaN            NaN
# 64            NaN          NaN          NaN   EN300-200298
#
#     all_reactants_in_enamine
# 5                      False
# 14                     False
# 18                     False
# 21                     False
# 22                     False
# 32                     False
# 33                     False
# 34                      True
# 36                     False
# 39                     False
# 49                     False
# 64                     False

# %%
df.to_csv('/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/sept23_syndirella_CHIKV_MAC_final_car_routes_w_enamine.csv', index=False)

# %%
df[df['all_reactants_in_enamine'] == False][df['num_steps']==2].to_csv('missing_two_step_routes.csv', index=False)
# Out:
# /tmp/ipykernel_306675/1794943044.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['all_reactants_in_enamine'] == False][df['num_steps']==2].to_csv('missing_two_step_routes.csv', index=False)
